# %% [markdown]
# <a href="https://colab.research.google.com/github/omnateeta/Generative-AI-Lab/blob/main/Genai_progeam_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#5. Use word embeddings to create meaningful sentences for creative tasks. Retrieve similar words for a
#seed word. Create a sentence or story using these words as a starting point. Write a program that: Takes a
s#eed word. Generates similar words. Constructs a short paragraph using these words.

# %%
# !pip install gensim

# %%
import gensim.downloader as api
import random

# %%
word_vectors = api.load("word2vec-google-news-300")
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
def create_story(seed_word):
    similar_words = [word for word, _ in word_vectors.most_similar(seed_word, topn=5)]

    story = f"Once upon a time, there was an {seed_word}. It lived in a world filled with "
    story += ", ".join(similar_words) + ". "

    story += f"Every day, the {seed_word} would explore new places, meeting {random.choice(similar_words)} and "
    story += f"learning about {random.choice(similar_words)}. "

    story += "It was an adventure every day!"

    return story

# %%
seed_word = "adventure"

story = create_story(seed_word)

print(story)
# Out:
# Once upon a time, there was an live. It lived in a world filled with living, Live, reside, GoFightLive.tv, lived. Every day, the live would explore new places, meeting reside and learning about Live. It was an adventure every day!
